# %% [markdown]
# ## Loading the data and basic exploration

# %%
# Importing Pandas
import pandas as pd

# %%
# Loading data into  pandas dataframe
df = pd.read_csv("home_price.csv")

# %%
# Running .head
df.head(30)
# Out:
#     Net_Metrekare  Brüt_Metrekare  Oda_Sayısı      Bulunduğu_Kat Eşya_Durumu  \
# 0             120           150.0         4.0              4.Kat      Eşyalı
# 1             100           125.0         4.0              3.Kat         Boş
# 2              89            95.0         3.0              4.Kat         Boş
# 3              40            55.0         2.0              6.Kat         Boş
# 4             140           150.0         4.0  Düz Giriş (Zemin)         Boş
# 5              40            55.0         2.0             12.Kat         Boş
# 6              90           110.0         3.0              2.Kat         NaN
# 7             180           750.0         5.0                NaN         Boş
# 8             105           145.0         4.0              8.Kat         NaN
# 9             110           130.0         4.0              4.Kat         NaN
# 10            100           120.0         3.0              2.Kat         Boş
# 11            130           145.0         4.0              2.Kat         Boş
# 12             90           110.0         3.0              2.Kat         Boş
# 13            100           120.0         4.0              2.Kat         Boş
# 14            140           150.0         4.0              5.Kat         Boş
# 15             45            50.0         2.0             14.Kat         Boş
# 16             45            60.0         2.0              4.Kat         Boş
# 17            220           250.0         5.0              8.Kat         Boş
# 18             80            95.0         3.0             12.Kat         NaN
# 19            280           300.0         6.0             16.Kat         NaN
# 20             85           110.0         3.0              1.Kat         Boş
# 21            125           175.0         4.5              1.Kat         Boş
# 22            140           150.0         4.0              6.Kat         Boş
# 23            195           200.0         5.0                NaN         NaN
# 24            110           130.0         4.0             17.Kat         Boş
# 25            130           140.0         4.0              4.Kat         NaN
# 26             70            80.0         3.0              2.Kat         NaN
# 27            200           250.0         6.0              9.Kat         Boş
# 28            110           160.0         4.0              5.Kat         NaN
# 29             80            90.0         3.0       Yüksek Giriş         Boş
#
#    Binanın_Yaşı          Isıtma_Tipi       Fiyat  Şehir  Binanın_Kat_Sayısı  \
# 0   21 Ve Üzeri       Kombi Doğalgaz    950000.0  adana                   6
# 1             4       Kombi Doğalgaz   1250000.0  adana                  10
# 2      0 (Yeni)       Kombi Doğalgaz   1750000.0  adana                  14
# 3      0 (Yeni)       Kombi Doğalgaz   1300000.0  adana                  14
# 4          5-10              Klimalı   1700000.0  adana                   4
# 5          5-10              Klimalı    765000.0  adana                  13
# 6      0 (Yeni)       Kombi Doğalgaz   1700000.0  adana                  14
# 7         16-20              Klimalı   3950000.0  adana                   2
# 8             4       Kombi Doğalgaz   1995000.0  adana                  11
# 9          5-10       Kombi Doğalgaz   2550000.0  adana                  11
# 10     0 (Yeni)       Kombi Doğalgaz   2465000.0  adana                   6
# 11        16-20       Kombi Doğalgaz   2085000.0  adana                   9
# 12         5-10              Klimalı   1785000.0  adana                   3
# 13            4       Kombi Doğalgaz   2090000.0  adana                  10
# 14            3              Klimalı   3200000.0  adana                   5
# 15     0 (Yeni)       Kombi Doğalgaz    975000.0  adana                  14
# 16     0 (Yeni)              Klimalı   1100000.0  adana                  12
# 17  21 Ve Üzeri       Kombi Doğalgaz   4200000.0  adana                  12
# 18     0 (Yeni)              Klimalı   1395000.0  adana                  13
# 19            4  Merkezi (Pay Ölçer)  13000000.0  adana                   3
# 20     0 (Yeni)       Kombi Doğalgaz   2370000.0  adana                  14
# 21         5-10       Kombi Doğalgaz   2700000.0  adana                  10
# 22  21 Ve Üzeri       Kombi Doğalgaz   2390000.0  adana                   8
# 23         5-10               Sobalı   4100000.0  adana                   2
# 24            3       Kombi Doğalgaz   3800000.0  adana                   3
# 25         5-10       Kombi Doğalgaz   2300000.0  adana                   4
# 26        16-20              Klimalı   1185000.0  adana                  12
# 27     0 (Yeni)       Kombi Doğalgaz   5498000.0  adana                  15
# 28  21 Ve Üzeri              Klimalı   1995000.0  adana                   7
# 29            2              Klimalı   1295000.0  adana                  10
#
#          Kullanım_Durumu Yatırıma_Uygunluk Takas    Tapu_Durumu  Banyo_Sayısı
# 0                    Boş               NaN   Var  Kat Mülkiyeti           1.0
# 1                    Boş               NaN   Var            NaN           1.0
# 2                    Boş             Uygun   Var            NaN           1.0
# 3                    Boş             Uygun   Yok            NaN           1.0
# 4                    Boş             Uygun   Yok  Kat Mülkiyeti           1.0
# 5        Kiracı Oturuyor               NaN   NaN  Kat Mülkiyeti           1.0
# 6                    Boş             Uygun   NaN            NaN           1.0
# 7   Mülk Sahibi Oturuyor             Uygun   NaN            NaN           1.0
# 8                    Boş             Uygun   NaN  Kat Mülkiyeti           1.0
# 9                    Boş             Uygun   Yok   Kat İrtifakı           1.0
# 10                   Boş               NaN   NaN  Kat Mülkiyeti           1.0
# 11                   Boş             Uygun   Yok  Kat Mülkiyeti           1.0
# 12       Kiracı Oturuyor             Uygun   Yok  Kat Mülkiyeti           1.0
# 13                   Boş             Uygun   Yok   Kat İrtifakı           1.0
# 14                   Boş             Uygun   Yok  Kat Mülkiyeti           2.0
# 15                   Boş             Uygun   Yok  Kat Mülkiyeti           1.0
# 16                   Boş        Bilinmiyor   Yok            NaN           1.0
# 17  Mülk Sahibi Oturuyor             Uygun   Var  Kat Mülkiyeti           1.0
# 18                   Boş        Bilinmiyor   Yok            NaN           1.0
# 19                   Boş               NaN   NaN            NaN           2.0
# 20                   Boş             Uygun   Yok  Kat Mülkiyeti           2.0
# 21                   Boş             Uygun   Var  Kat Mülkiyeti           2.0
# 22                   Boş             Uygun   Var  Kat Mülkiyeti           1.0
# 23       Kiracı Oturuyor        Bilinmiyor   Var            NaN           1.0
# 24  Mülk Sahibi Oturuyor             Uygun   Var   Kat İrtifakı           2.0
# 25  Mülk Sahibi Oturuyor               NaN   NaN            NaN           2.0
# 26                   Boş             Uygun   NaN            NaN           1.0
# 27                   Boş               NaN   NaN            NaN           2.0
# 28                   Boş        Bilinmiyor   Yok            NaN           1.0
# 29                   Boş        Bilinmiyor   Yok            NaN           1.0

# %%
# Running .info to get a basic idea of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20326 entries, 0 to 20325
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Net_Metrekare       20326 non-null  int64
#  1   Brüt_Metrekare      20326 non-null  float64
#  2   Oda_Sayısı          20066 non-null  float64
#  3   Bulunduğu_Kat       18029 non-null  object
#  4   Eşya_Durumu         12928 non-null  object
#  5   Binanın_Yaşı        20326 non-null  object
#  6   Isıtma_Tipi         20326 non-null  object
#  7   Fiyat               20326 non-null  float64
#  8   Şehir               20326 non-null  object
#  9   Binanın_Kat_Sayısı  20326 non-null  int64
#  10  Kullanım_Durumu     20326 non-null  object
#  11  Yatırıma_Uygunluk   14750 non-null  object
#  12  Takas               14431 non-null  object
#  13  Tapu_Durumu         9760 non-null   object
#  14  Banyo_Sayısı        20280 non-null  float64
# dtypes: float64(4), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
# Running .describe for the same purpose
df.describe()
# Out:
#        Net_Metrekare  Brüt_Metrekare   Oda_Sayısı         Fiyat  \
# count   20326.000000    2.032600e+04  20066.00000  2.032600e+04
# mean      151.964528    1.437683e+09      3.68940  4.649510e+06
# std      1137.304466    2.049686e+11      1.11206  7.136120e+07
# min         0.000000    2.000000e+00      1.00000  2.000000e+04
# 25%        90.000000    1.000000e+02      3.00000  1.640000e+06
# 50%       120.000000    1.350000e+02      4.00000  2.300000e+06
# 75%       150.000000    1.700000e+02      4.00000  3.300000e+06
# max    110000.000000    2.922222e+13     12.00000  7.500000e+09
#
#        Binanın_Kat_Sayısı  Banyo_Sayısı
# count        20326.000000  20280.000000
# mean             5.185969      1.492751
# std              3.051288      0.795747
# min              1.000000      0.000000
# 25%              3.000000      1.000000
# 50%              4.000000      1.000000
# 75%              6.000000      2.000000
# max             15.000000      6.000000

# %%
# Running .isna to check for null rows
df.isna()
# Out:
#        Net_Metrekare  Brüt_Metrekare  Oda_Sayısı  Bulunduğu_Kat  Eşya_Durumu  \
# 0              False           False       False          False        False
# 1              False           False       False          False        False
# 2              False           False       False          False        False
# 3              False           False       False          False        False
# 4              False           False       False          False        False
# ...              ...             ...         ...            ...          ...
# 20321          False           False       False          False         True
# 20322          False           False       False          False         True
# 20323          False           False       False          False         True
# 20324          False           False       False          False         True
# 20325          False           False       False          False         True
#
#        Binanın_Yaşı  Isıtma_Tipi  Fiyat  Şehir  Binanın_Kat_Sayısı  \
# 0             False        False  False  False               False
# 1             False        False  False  False               False
# 2             False        False  False  False               False
# 3             False        False  False  False               False
# 4             False        False  False  False               False
# ...             ...          ...    ...    ...                 ...
# 20321         False        False  False  False               False
# 20322         False        False  False  False               False
# 20323         False        False  False  False               False
# 20324         False        False  False  False               False
# 20325         False        False  False  False               False
#
#        Kullanım_Durumu  Yatırıma_Uygunluk  Takas  Tapu_Durumu  Banyo_Sayısı
# 0                False               True  False        False         False
# 1                False               True  False         True         False
# 2                False              False  False         True         False
# 3                False              False  False         True         False
# 4                False              False  False        False         False
# ...                ...                ...    ...          ...           ...
# 20321            False               True   True         True          True
# 20322            False               True  False        False         False
# 20323            False               True   True         True          True
# 20324            False               True   True         True          True
# 20325            False               True   True         True          True
#
# [20326 rows x 15 columns]

# %%
# Chaining multiple methods for a more accurate count of null rows, courtesy gemini
rows_with_null = df.isna().any(axis=1).sum()
print(rows_with_null)
# Out:
# 15135

# %%
# Checking total number of rows for context
num_rows = len(df)
print(num_rows)
# Out:
# 20326

# %%
# A whopping 74.5% of my dataset has null rows.

# %% [markdown]
# ## Removing Duplicates

# %%
# Counting rows with duplicates, courtesy gemini
duplicate_count = df.duplicated().sum()

# %%
print("Duplicate rows: " + str(duplicate_count))
# Out:
# Duplicate rows: 195

# %%
# ELiminating duplicate rows, courtesy gemini
df = df.drop_duplicates(keep='first', ignore_index=True)
# Verifying ELimination
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ## Ensuring all columns have the correct data types

# %%
# Handling non-numeric values in numeric columns
# Target columns that are currently numeric (int or float)
numeric_cols = df.select_dtypes(include=['number']).columns.tolist()

anomalies_found = 0

print("--- Checking and Fixing Non-Numeric Data in Numeric Columns ---")

for col in numeric_cols:
    # 1. Temporarily coerce the column to numeric, turning non-convertible strings into NaN
    temp_numeric = pd.to_numeric(df[col], errors='coerce')

    # 2. Identify where conversion failed AND the original value was NOT already NaN
    # This isolates the actual 'wrong kind of data' (e.g., '---' or 'error code')
    is_anomaly = temp_numeric.isna() & df[col].notna()
    
    count_of_bad_data = is_anomaly.sum()
    
    if count_of_bad_data > 0:
        anomalies_found += count_of_bad_data
        
        # 3. Apply the fix: Overwrite the original column, replacing bad data with NaN
        df[col] = temp_numeric 
        
        print(f"| FIXED: '{col}' - {count_of_bad_data} non-numeric values converted to NaN.")

print("\n--- Summary (Part 1) ---")
if anomalies_found > 0:
    print(f"Successfully converted {anomalies_found} structural errors to NaN across the dataset.")
else:
    print("✅ No non-numeric data anomalies found in current numeric columns.")
# Out:
# --- Checking and Fixing Non-Numeric Data in Numeric Columns ---
#
# --- Summary (Part 1) ---
# ✅ No non-numeric data anomalies found in current numeric columns.

# %%
# Forcing all the elements in categorical columns into category, to ensure consistent behaviour later on
# Selects all columns that Pandas currently registers as 'object'
object_cols = df.select_dtypes(include=['object']).columns

print("--- Enforcing String Type for Object Columns ---")

for col in object_cols:
    # Convert every value in the column to a string
    df[col] = df[col].astype(str)
    
    # Optional: Convert to 'category' dtype for memory efficiency
    # If the column has fewer than 50 unique values, this is a good idea.
    if df[col].nunique() < 50: 
        df[col] = df[col].astype('category')
        print(f"| Column '{col}' converted to category.")
    else:
        print(f"| Column '{col}' converted to object (string).")

print("--- All target columns are now consistently string/category type. ---")
# Out:
# --- Enforcing String Type for Object Columns ---
# | Column 'Bulunduğu_Kat' converted to category.
# | Column 'Eşya_Durumu' converted to category.
# | Column 'Binanın_Yaşı' converted to category.
# | Column 'Isıtma_Tipi' converted to category.
# | Column 'Şehir' converted to object (string).
# | Column 'Kullanım_Durumu' converted to category.
# | Column 'Yatırıma_Uygunluk' converted to category.
# | Column 'Takas' converted to category.
# | Column 'Tapu_Durumu' converted to category.
# --- All target columns are now consistently string/category type. ---

# %% [markdown]
# ## Handling null values

# %% [markdown]
# . Handling null values in numerical columns

# %%
# Handling null values in numerical columns
# 1. Identify all numerical columns (int and float)
# This includes the columns where you fixed the data type anomalies previously.
numerical_cols = df.select_dtypes(include=['number']).columns

print("--- Starting Numerical Imputation (Median) ---")
imputed_cols = 0

for col in numerical_cols:
    # 2. Check if the column has any missing values
    if df[col].isnull().any():
        
        # 3. Calculate the median for the current column
        # .median() ignores NaN values automatically when calculating.
        median_value = df[col].median()
        
        # 4. Fill the NaN values with the calculated median
        df[col].fillna(median_value, inplace=True)
        
        # Count the number of cells imputed
        num_imputed = df[col].isnull().sum()
        
        # Re-check to confirm successful imputation (should be 0)
        if num_imputed == 0:
            print(f"| Imputed '{col}' with median value ({median_value:.2f}).")
            imputed_cols += 1
        else:
            print(f"| WARNING: Column '{col}' failed to fully impute.")
            
print("\n--- Summary ---")
if imputed_cols > 0:
    print(f"✅ Successfully imputed missing values in {imputed_cols} numerical columns.")
else:
    print("ℹ️ No missing values found in the numerical columns or all were already handled.")
# Out:
# --- Starting Numerical Imputation (Median) ---
# | Imputed 'Oda_Sayısı' with median value (4.00).
# | Imputed 'Banyo_Sayısı' with median value (1.00).
#
# --- Summary ---
# ✅ Successfully imputed missing values in 2 numerical columns.
# C:\Users\amets\AppData\Local\Temp\ipykernel_12716\2903304380.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\amets\AppData\Local\Temp\ipykernel_12716\2903304380.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)

# %%
# Verifying
rows_with_null_2 = df.isna().any(axis=1).sum()
print(rows_with_null)
# Out:
# 15135

# %%
# Checking current dataset situation
df.head(20)
# Out:
#     Net_Metrekare  Brüt_Metrekare  Oda_Sayısı      Bulunduğu_Kat Eşya_Durumu  \
# 0             120           150.0         4.0              4.Kat      Eşyalı
# 1             100           125.0         4.0              3.Kat         Boş
# 2              89            95.0         3.0              4.Kat         Boş
# 3              40            55.0         2.0              6.Kat         Boş
# 4             140           150.0         4.0  Düz Giriş (Zemin)         Boş
# 5              40            55.0         2.0             12.Kat         Boş
# 6              90           110.0         3.0              2.Kat         nan
# 7             180           750.0         5.0                nan         Boş
# 8             105           145.0         4.0              8.Kat         nan
# 9             110           130.0         4.0              4.Kat         nan
# 10            100           120.0         3.0              2.Kat         Boş
# 11            130           145.0         4.0              2.Kat         Boş
# 12             90           110.0         3.0              2.Kat         Boş
# 13            100           120.0         4.0              2.Kat         Boş
# 14            140           150.0         4.0              5.Kat         Boş
# 15             45            50.0         2.0             14.Kat         Boş
# 16             45            60.0         2.0              4.Kat         Boş
# 17            220           250.0         5.0              8.Kat         Boş
# 18             80            95.0         3.0             12.Kat         nan
# 19            280           300.0         6.0             16.Kat         nan
#
#    Binanın_Yaşı          Isıtma_Tipi       Fiyat  Şehir  Binanın_Kat_Sayısı  \
# 0   21 Ve Üzeri       Kombi Doğalgaz    950000.0  adana                   6
# 1             4       Kombi Doğalgaz   1250000.0  adana                  10
# 2      0 (Yeni)       Kombi Doğalgaz   1750000.0  adana                  14
# 3      0 (Yeni)       Kombi Doğalgaz   1300000.0  adana                  14
# 4          5-10              Klimalı   1700000.0  adana                   4
# 5          5-10              Klimalı    765000.0  adana                  13
# 6      0 (Yeni)       Kombi Doğalgaz   1700000.0  adana                  14
# 7         16-20              Klimalı   3950000.0  adana                   2
# 8             4       Kombi Doğalgaz   1995000.0  adana                  11
# 9          5-10       Kombi Doğalgaz   2550000.0  adana                  11
# 10     0 (Yeni)       Kombi Doğalgaz   2465000.0  adana                   6
# 11        16-20       Kombi Doğalgaz   2085000.0  adana                   9
# 12         5-10              Klimalı   1785000.0  adana                   3
# 13            4       Kombi Doğalgaz   2090000.0  adana                  10
# 14            3              Klimalı   3200000.0  adana                   5
# 15     0 (Yeni)       Kombi Doğalgaz    975000.0  adana                  14
# 16     0 (Yeni)              Klimalı   1100000.0  adana                  12
# 17  21 Ve Üzeri       Kombi Doğalgaz   4200000.0  adana                  12
# 18     0 (Yeni)              Klimalı   1395000.0  adana                  13
# 19            4  Merkezi (Pay Ölçer)  13000000.0  adana                   3
#
#          Kullanım_Durumu Yatırıma_Uygunluk Takas    Tapu_Durumu  Banyo_Sayısı
# 0                    Boş               nan   Var  Kat Mülkiyeti           1.0
# 1                    Boş               nan   Var            nan           1.0
# 2                    Boş             Uygun   Var            nan           1.0
# 3                    Boş             Uygun   Yok            nan           1.0
# 4                    Boş             Uygun   Yok  Kat Mülkiyeti           1.0
# 5        Kiracı Oturuyor               nan   nan  Kat Mülkiyeti           1.0
# 6                    Boş             Uygun   nan            nan           1.0
# 7   Mülk Sahibi Oturuyor             Uygun   nan            nan           1.0
# 8                    Boş             Uygun   nan  Kat Mülkiyeti           1.0
# 9                    Boş             Uygun   Yok   Kat İrtifakı           1.0
# 10                   Boş               nan   nan  Kat Mülkiyeti           1.0
# 11                   Boş             Uygun   Yok  Kat Mülkiyeti           1.0
# 12       Kiracı Oturuyor             Uygun   Yok  Kat Mülkiyeti           1.0
# 13                   Boş             Uygun   Yok   Kat İrtifakı           1.0
# 14                   Boş             Uygun   Yok  Kat Mülkiyeti           2.0
# 15                   Boş             Uygun   Yok  Kat Mülkiyeti           1.0
# 16                   Boş        Bilinmiyor   Yok            nan           1.0
# 17  Mülk Sahibi Oturuyor             Uygun   Var  Kat Mülkiyeti           1.0
# 18                   Boş        Bilinmiyor   Yok            nan           1.0
# 19                   Boş               nan   nan            nan           2.0

# %% [markdown]
# .. Handling null values in categorical columns

# %%
# Will replace all nan items with missing as that lowers the risk of bias and overfitting

# %%
import pandas as pd

# Define the string that represents the missing value in your categorical columns
MISSING_VALUE_STRING = 'nan'

# Define the new, informative category name
NEW_CATEGORY_NAME = 'Bilinmiyor'

# 1. Identify all non-numerical columns
categorical_cols = df.select_dtypes(exclude=['number']).columns

print("--- Starting Categorical Imputation (FIXED) ---")
imputed_cols = 0

for col in categorical_cols:
    # Check if the column is a true 'category' dtype
    is_categorical_dtype = df[col].dtype.name == 'category'
    
    # 2. Check if the new category is already registered (prevents error if run twice)
    if is_categorical_dtype and NEW_CATEGORY_NAME not in df[col].cat.categories:
        # Add the new category to the column's master list
        df[col] = df[col].cat.add_categories(NEW_CATEGORY_NAME)
        print(f"| Added '{NEW_CATEGORY_NAME}' to categories for column '{col}'.")
    
    # 3. Create a Boolean mask to find where the value equals the missing string
    is_missing = (df[col].astype(str).str.lower() == MISSING_VALUE_STRING)
    
    count_to_impute = is_missing.sum()
    
    if count_to_impute > 0:
        
        # 4. Use .loc[] to efficiently replace the missing strings with the new category name
        # This assignment will now work because the category has been pre-registered.
        df.loc[is_missing, col] = NEW_CATEGORY_NAME
        
        print(f"| Imputed '{col}': Replaced {count_to_impute} instances of '{MISSING_VALUE_STRING}' with '{NEW_CATEGORY_NAME}'.")
        imputed_cols += 1
    
print("\n--- Summary ---")
if imputed_cols > 0:
    print(f"✅ Successfully imputed missing values in {imputed_cols} categorical columns.")
else:
    print("ℹ️ No string-based missing values were found.")
# Out:
# --- Starting Categorical Imputation (FIXED) ---
# | Added 'Bilinmiyor' to categories for column 'Bulunduğu_Kat'.
# | Imputed 'Bulunduğu_Kat': Replaced 2272 instances of 'nan' with 'Bilinmiyor'.
# | Added 'Bilinmiyor' to categories for column 'Eşya_Durumu'.
# | Imputed 'Eşya_Durumu': Replaced 7323 instances of 'nan' with 'Bilinmiyor'.
# | Added 'Bilinmiyor' to categories for column 'Binanın_Yaşı'.
# | Added 'Bilinmiyor' to categories for column 'Isıtma_Tipi'.
# | Added 'Bilinmiyor' to categories for column 'Kullanım_Durumu'.
# | Imputed 'Yatırıma_Uygunluk': Replaced 5532 instances of 'nan' with 'Bilinmiyor'.
# | Added 'Bilinmiyor' to categories for column 'Takas'.
# | Imputed 'Takas': Replaced 5842 instances of 'nan' with 'Bilinmiyor'.
# | Imputed 'Tapu_Durumu': Replaced 10472 instances of 'nan' with 'Bilinmiyor'.
#
# --- Summary ---
# ✅ Successfully imputed missing values in 5 categorical columns.

# %%
# Verifying success
df.head(20)
# Out:
#     Net_Metrekare  Brüt_Metrekare  Oda_Sayısı      Bulunduğu_Kat Eşya_Durumu  \
# 0             120           150.0         4.0              4.Kat      Eşyalı
# 1             100           125.0         4.0              3.Kat         Boş
# 2              89            95.0         3.0              4.Kat         Boş
# 3              40            55.0         2.0              6.Kat         Boş
# 4             140           150.0         4.0  Düz Giriş (Zemin)         Boş
# 5              40            55.0         2.0             12.Kat         Boş
# 6              90           110.0         3.0              2.Kat  Bilinmiyor
# 7             180           750.0         5.0         Bilinmiyor         Boş
# 8             105           145.0         4.0              8.Kat  Bilinmiyor
# 9             110           130.0         4.0              4.Kat  Bilinmiyor
# 10            100           120.0         3.0              2.Kat         Boş
# 11            130           145.0         4.0              2.Kat         Boş
# 12             90           110.0         3.0              2.Kat         Boş
# 13            100           120.0         4.0              2.Kat         Boş
# 14            140           150.0         4.0              5.Kat         Boş
# 15             45            50.0         2.0             14.Kat         Boş
# 16             45            60.0         2.0              4.Kat         Boş
# 17            220           250.0         5.0              8.Kat         Boş
# 18             80            95.0         3.0             12.Kat  Bilinmiyor
# 19            280           300.0         6.0             16.Kat  Bilinmiyor
#
#    Binanın_Yaşı          Isıtma_Tipi       Fiyat  Şehir  Binanın_Kat_Sayısı  \
# 0   21 Ve Üzeri       Kombi Doğalgaz    950000.0  adana                   6
# 1             4       Kombi Doğalgaz   1250000.0  adana                  10
# 2      0 (Yeni)       Kombi Doğalgaz   1750000.0  adana                  14
# 3      0 (Yeni)       Kombi Doğalgaz   1300000.0  adana                  14
# 4          5-10              Klimalı   1700000.0  adana                   4
# 5          5-10              Klimalı    765000.0  adana                  13
# 6      0 (Yeni)       Kombi Doğalgaz   1700000.0  adana                  14
# 7         16-20              Klimalı   3950000.0  adana                   2
# 8             4       Kombi Doğalgaz   1995000.0  adana                  11
# 9          5-10       Kombi Doğalgaz   2550000.0  adana                  11
# 10     0 (Yeni)       Kombi Doğalgaz   2465000.0  adana                   6
# 11        16-20       Kombi Doğalgaz   2085000.0  adana                   9
# 12         5-10              Klimalı   1785000.0  adana                   3
# 13            4       Kombi Doğalgaz   2090000.0  adana                  10
# 14            3              Klimalı   3200000.0  adana                   5
# 15     0 (Yeni)       Kombi Doğalgaz    975000.0  adana                  14
# 16     0 (Yeni)              Klimalı   1100000.0  adana                  12
# 17  21 Ve Üzeri       Kombi Doğalgaz   4200000.0  adana                  12
# 18     0 (Yeni)              Klimalı   1395000.0  adana                  13
# 19            4  Merkezi (Pay Ölçer)  13000000.0  adana                   3
#
#          Kullanım_Durumu Yatırıma_Uygunluk       Takas    Tapu_Durumu  \
# 0                    Boş        Bilinmiyor         Var  Kat Mülkiyeti
# 1                    Boş        Bilinmiyor         Var     Bilinmiyor
# 2                    Boş             Uygun         Var     Bilinmiyor
# 3                    Boş             Uygun         Yok     Bilinmiyor
# 4                    Boş             Uygun         Yok  Kat Mülkiyeti
# 5        Kiracı Oturuyor        Bilinmiyor  Bilinmiyor  Kat Mülkiyeti
# 6                    Boş             Uygun  Bilinmiyor     Bilinmiyor
# 7   Mülk Sahibi Oturuyor             Uygun  Bilinmiyor     Bilinmiyor
# 8                    Boş             Uygun  Bilinmiyor  Kat Mülkiyeti
# 9                    Boş             Uygun         Yok   Kat İrtifakı
# 10                   Boş        Bilinmiyor  Bilinmiyor  Kat Mülkiyeti
# 11                   Boş             Uygun         Yok  Kat Mülkiyeti
# 12       Kiracı Oturuyor             Uygun         Yok  Kat Mülkiyeti
# 13                   Boş             Uygun         Yok   Kat İrtifakı
# 14                   Boş             Uygun         Yok  Kat Mülkiyeti
# 15                   Boş             Uygun         Yok  Kat Mülkiyeti
# 16                   Boş        Bilinmiyor         Yok     Bilinmiyor
# 17  Mülk Sahibi Oturuyor             Uygun         Var  Kat Mülkiyeti
# 18                   Boş        Bilinmiyor         Yok     Bilinmiyor
# 19                   Boş        Bilinmiyor  Bilinmiyor     Bilinmiyor
#
#     Banyo_Sayısı
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# 5            1.0
# 6            1.0
# 7            1.0
# 8            1.0
# 9            1.0
# 10           1.0
# 11           1.0
# 12           1.0
# 13           1.0
# 14           2.0
# 15           1.0
# 16           1.0
# 17           1.0
# 18           1.0
# 19           2.0

# %% [markdown]
# ## Handling Outliers

# %%
import pandas as pd
df = pd.read_csv("home_price.csv") 
df.describe()
# Out:
#        Net_Metrekare  Brüt_Metrekare   Oda_Sayısı         Fiyat  \
# count   20326.000000    2.032600e+04  20066.00000  2.032600e+04
# mean      151.964528    1.437683e+09      3.68940  4.649510e+06
# std      1137.304466    2.049686e+11      1.11206  7.136120e+07
# min         0.000000    2.000000e+00      1.00000  2.000000e+04
# 25%        90.000000    1.000000e+02      3.00000  1.640000e+06
# 50%       120.000000    1.350000e+02      4.00000  2.300000e+06
# 75%       150.000000    1.700000e+02      4.00000  3.300000e+06
# max    110000.000000    2.922222e+13     12.00000  7.500000e+09
#
#        Binanın_Kat_Sayısı  Banyo_Sayısı
# count        20326.000000  20280.000000
# mean             5.185969      1.492751
# std              3.051288      0.795747
# min              1.000000      0.000000
# 25%              3.000000      1.000000
# 50%              4.000000      1.000000
# 75%              6.000000      2.000000
# max             15.000000      6.000000

# %%
# Checking for outliers in numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64'])

Q1 = num_cols.quantile(0.25)
Q3 = num_cols.quantile(0.75)
IQR = Q3 - Q1

outliers = num_cols[(num_cols < (Q1 - 1.5 * IQR)) | (num_cols > (Q3 + 1.5 * IQR))]

print(outliers.dropna(how="all"))
# Out:
#        Net_Metrekare  Brüt_Metrekare  Oda_Sayısı      Fiyat  \
# 2                NaN             NaN         NaN        NaN
# 3                NaN             NaN         NaN        NaN
# 5                NaN             NaN         NaN        NaN
# 6                NaN             NaN         NaN        NaN
# 7                NaN           750.0         NaN        NaN
# ...              ...             ...         ...        ...
# 20269          256.0             NaN         NaN        NaN
# 20287          674.0           675.0         NaN        NaN
# 20291            NaN           378.0         NaN        NaN
# 20302            NaN             NaN         NaN  6850000.0
# 20311          463.0           464.0         NaN  7850000.0
#
#        Binanın_Kat_Sayısı  Banyo_Sayısı
# 2                    14.0           NaN
# 3                    14.0           NaN
# 5                    13.0           NaN
# 6                    14.0           NaN
# 7                     NaN           NaN
# ...                   ...           ...
# 20269                 NaN           NaN
# 20287                 NaN           NaN
# 20291                 NaN           NaN
# 20302                 NaN           NaN
# 20311                 NaN           NaN
#
# [4569 rows x 6 columns]

# %%
print("### Outlier Cleaning (Capping) on Numerical Columns ###")

def clip_outliers(df, columns):
    for col in columns:
        lower = df[col].quantile(0.01)
        upper = df[col].quantile(0.99)
        df[col] = df[col].clip(lower=lower, upper=upper)
    return df

df = clip_outliers(df, ['Fiyat', 'Net_Metrekare', 'Brüt_Metrekare'])
df.describe()
# Out:
# ### Outlier Cleaning (Capping) on Numerical Columns ###
#        Net_Metrekare  Brüt_Metrekare   Oda_Sayısı         Fiyat  \
# count   20326.000000    20326.000000  20066.00000  2.032600e+04
# mean      128.636721      154.662600      3.68940  3.128497e+06
# std        69.270094      108.833169      1.11206  2.988716e+06
# min        40.000000       47.000000      1.00000  6.112500e+05
# 25%        90.000000      100.000000      3.00000  1.640000e+06
# 50%       120.000000      135.000000      4.00000  2.300000e+06
# 75%       150.000000      170.000000      4.00000  3.300000e+06
# max       500.000000      833.000000     12.00000  1.983750e+07
#
#        Binanın_Kat_Sayısı  Banyo_Sayısı
# count        20326.000000  20280.000000
# mean             5.185969      1.492751
# std              3.051288      0.795747
# min              1.000000      0.000000
# 25%              3.000000      1.000000
# 50%              4.000000      1.000000
# 75%              6.000000      2.000000
# max             15.000000      6.000000

# %%
# End of outlier handling

# %%
df.head(20)
# Out:
#     Net_Metrekare  Brüt_Metrekare  Oda_Sayısı      Bulunduğu_Kat Eşya_Durumu  \
# 0             120           150.0         4.0              4.Kat      Eşyalı
# 1             100           125.0         4.0              3.Kat         Boş
# 2              89            95.0         3.0              4.Kat         Boş
# 3              40            55.0         2.0              6.Kat         Boş
# 4             140           150.0         4.0  Düz Giriş (Zemin)         Boş
# 5              40            55.0         2.0             12.Kat         Boş
# 6              90           110.0         3.0              2.Kat         NaN
# 7             180           750.0         5.0                NaN         Boş
# 8             105           145.0         4.0              8.Kat         NaN
# 9             110           130.0         4.0              4.Kat         NaN
# 10            100           120.0         3.0              2.Kat         Boş
# 11            130           145.0         4.0              2.Kat         Boş
# 12             90           110.0         3.0              2.Kat         Boş
# 13            100           120.0         4.0              2.Kat         Boş
# 14            140           150.0         4.0              5.Kat         Boş
# 15             45            50.0         2.0             14.Kat         Boş
# 16             45            60.0         2.0              4.Kat         Boş
# 17            220           250.0         5.0              8.Kat         Boş
# 18             80            95.0         3.0             12.Kat         NaN
# 19            280           300.0         6.0             16.Kat         NaN
#
#    Binanın_Yaşı          Isıtma_Tipi       Fiyat  Şehir  Binanın_Kat_Sayısı  \
# 0   21 Ve Üzeri       Kombi Doğalgaz    950000.0  adana                   6
# 1             4       Kombi Doğalgaz   1250000.0  adana                  10
# 2      0 (Yeni)       Kombi Doğalgaz   1750000.0  adana                  14
# 3      0 (Yeni)       Kombi Doğalgaz   1300000.0  adana                  14
# 4          5-10              Klimalı   1700000.0  adana                   4
# 5          5-10              Klimalı    765000.0  adana                  13
# 6      0 (Yeni)       Kombi Doğalgaz   1700000.0  adana                  14
# 7         16-20              Klimalı   3950000.0  adana                   2
# 8             4       Kombi Doğalgaz   1995000.0  adana                  11
# 9          5-10       Kombi Doğalgaz   2550000.0  adana                  11
# 10     0 (Yeni)       Kombi Doğalgaz   2465000.0  adana                   6
# 11        16-20       Kombi Doğalgaz   2085000.0  adana                   9
# 12         5-10              Klimalı   1785000.0  adana                   3
# 13            4       Kombi Doğalgaz   2090000.0  adana                  10
# 14            3              Klimalı   3200000.0  adana                   5
# 15     0 (Yeni)       Kombi Doğalgaz    975000.0  adana                  14
# 16     0 (Yeni)              Klimalı   1100000.0  adana                  12
# 17  21 Ve Üzeri       Kombi Doğalgaz   4200000.0  adana                  12
# 18     0 (Yeni)              Klimalı   1395000.0  adana                  13
# 19            4  Merkezi (Pay Ölçer)  13000000.0  adana                   3
#
#          Kullanım_Durumu Yatırıma_Uygunluk Takas    Tapu_Durumu  Banyo_Sayısı
# 0                    Boş               NaN   Var  Kat Mülkiyeti           1.0
# 1                    Boş               NaN   Var            NaN           1.0
# 2                    Boş             Uygun   Var            NaN           1.0
# 3                    Boş             Uygun   Yok            NaN           1.0
# 4                    Boş             Uygun   Yok  Kat Mülkiyeti           1.0
# 5        Kiracı Oturuyor               NaN   NaN  Kat Mülkiyeti           1.0
# 6                    Boş             Uygun   NaN            NaN           1.0
# 7   Mülk Sahibi Oturuyor             Uygun   NaN            NaN           1.0
# 8                    Boş             Uygun   NaN  Kat Mülkiyeti           1.0
# 9                    Boş             Uygun   Yok   Kat İrtifakı           1.0
# 10                   Boş               NaN   NaN  Kat Mülkiyeti           1.0
# 11                   Boş             Uygun   Yok  Kat Mülkiyeti           1.0
# 12       Kiracı Oturuyor             Uygun   Yok  Kat Mülkiyeti           1.0
# 13                   Boş             Uygun   Yok   Kat İrtifakı           1.0
# 14                   Boş             Uygun   Yok  Kat Mülkiyeti           2.0
# 15                   Boş             Uygun   Yok  Kat Mülkiyeti           1.0
# 16                   Boş        Bilinmiyor   Yok            NaN           1.0
# 17  Mülk Sahibi Oturuyor             Uygun   Var  Kat Mülkiyeti           1.0
# 18                   Boş        Bilinmiyor   Yok            NaN           1.0
# 19                   Boş               NaN   NaN            NaN           2.0

# %% [markdown]
# # EDA

# %% [markdown]
# ## Univariate analysis with histograms and boxplots

# %% [markdown]
# ### Using Histograms to check distribution of numerical features

# %%
# Importing functionality
import matplotlib.pyplot as plt

# %%
# Checking distribution of net metrekare
plt.hist(df["Net_Metrekare"])
plt.xlabel("Net meterage", fontsize = 12)
plt.ylabel("Number of houses", fontsize = 12)
plt.show()

# %%
# Checking Gross metrekare, which counts in wall thickness, unlike net metrekare
plt.hist(df["Brüt_Metrekare"])
plt.xlabel("Gross Metreage", fontsize = 12)
plt.ylabel("Number of houses", fontsize = 12)
plt.show()

# %%
# Observation 1: Both net metre kare and brut metrekare are skewed to the left, but Brut metrekare is more skewed

# %%
# Checking oda sayısı
plt.hist(df["Oda_Sayısı"])
plt.xlabel("Number of rooms", fontsize = 12)
plt.ylabel("Number of houses", fontsize = 12)
plt.show()

# %%
# Checking fiyat
plt.hist(df["Fiyat"])
plt.xlabel("Price", fontsize = 12)
plt.ylabel("Number of houses", fontsize = 12)
plt.show()

# %%
# Observation 2: The price distribution is very skewed to the lower end of the market

# %%
# Checking Binanin kat sayisi
plt.hist(df["Binanın_Kat_Sayısı"])
plt.xlabel("Number of floors of building", fontsize = 12)
plt.ylabel("Number of houses", fontsize = 12)
plt.show()

# %%
# Observation 3: most buildings in the dataset seem to be at most 5 floors tall

# %%
# Checking Banyo_Sayısı
plt.hist(df["Banyo_Sayısı"])
plt.xlabel("Number of Bathrooms", fontsize = 12)
plt.ylabel("Number of houses", fontsize = 12)
plt.show()

# %%
# Observation 4: Overwhelming majority of houses have one bathroom, some have 2, but less than
# 1000 have more

# %% [markdown]
# ### Using boxplots to conduct further univariate analysis

# %%
# Checking Net_metrekare
df.boxplot(column = "Net_Metrekare")
# Out:
# <Axes: >

# %%
# Checking Brüt_Metrekare
df.boxplot(column = "Brüt_Metrekare")
# Out:
# <Axes: >

# %%
# Checking Oda_Sayısı
df.boxplot(column = "Oda_Sayısı")
# Out:
# <Axes: >

# %%
# Checking Fiyat
df.boxplot(column = "Fiyat")
# Out:
# <Axes: >

# %%
# Checking Binanın_Kat_Sayısı
df.boxplot(column = "Binanın_Kat_Sayısı")
# Out:
# <Axes: >

# %%
# Checking Binanın_Kat_Sayısı
df.boxplot(column = "Banyo_Sayısı")
# Out:
# <Axes: >

# %%
# A lot of outliers it seems.

# %% [markdown]
# ## Bivariate analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Correlation Analysis (Heatmap)

# %%
numeric_cols = ['Fiyat', 'Net_Metrekare', 'Brüt_Metrekare', 'Oda_Sayısı', 'Banyo_Sayısı', 'Binanın_Kat_Sayısı']

plt.figure(figsize=(10, 8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Inferences
# Looking at the data, there isn't really a strong connection between the variables. The size of the house and the number of bathrooms are the best indicators we have. As you’d expect, bigger homes naturally come with more rooms, but interestingly, the height of the building—how many floors it has—is basically irrelevant and doesn't really impact the price tag at all.

# %% [markdown]
# ### Scatter Plots

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 6))

# --- 1. Brüt Metrekare ve Fiyat İlişkisi ---
sns.scatterplot(data=df, x='Brüt_Metrekare', y='Fiyat', alpha=0.6, color='darkblue', ax=axes[0])
axes[0].set_title('Brüt Metrekare ve Fiyat İlişkisi')
axes[0].set_xlabel('Brüt Metrekare (m²)')
axes[0].set_ylabel('Fiyat (10 Milyon TL)')

# --- 2. Net Metrekare ve Fiyat İlişkisi ---
sns.scatterplot(data=df, x='Net_Metrekare', y='Fiyat', alpha=0.6, color='darkred', ax=axes[1]) # Rengi ayırt edilsin diye darkred yaptım
axes[1].set_title('Net Metrekare ve Fiyat İlişkisi')
axes[1].set_xlabel('Net Metrekare (m²)')
axes[1].set_ylabel('Fiyat (10 Milyon TL)')
plt.tight_layout()

# %% [markdown]
# ### Inferences
#  At first, it looks like price and size go hand in hand. But as the properties get bigger, that connection starts to fall apart. For large houses, prices are all over the place, which shows that size isn't the only thing driving the cost anymore. It gets totally unpredictable, and you can't really rely on square footage alone.

# %% [markdown]
# ## Box Plot

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Oda_Sayısı', y='Fiyat', palette='viridis')
plt.title('Oda Sayısına Göre Fiyat Dağılımı')
plt.xlabel('Oda Sayısı')
plt.ylabel('Fiyat (TL)')
plt.ticklabel_format(style='plain', axis='y')
plt.show()
# Out:
# C:\Users\amets\AppData\Local\Temp\ipykernel_12716\2650882590.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Oda_Sayısı', y='Fiyat', palette='viridis')

# %% [markdown]
# ### Inferences
# The chart shows that while having more rooms generally raises the price, it’s not a strict rule. Standard homes with 2 to 5 rooms see huge price differences, proving that factors like luxury or location can make a small apartment cost as much as a mansion. Also, for very large properties, the prices are all over the place, making it clear that you can't predict a home's value just by counting its rooms.

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6), gridspec_kw={'width_ratios': [3, 1]})

# --- 1. Top 10 Şehir ---
top_cities = df['Şehir'].value_counts().nlargest(10).index
sns.boxplot(data=df[df['Şehir'].isin(top_cities)], x='Şehir', y='Fiyat', palette='Set2', ax=axes[0])

axes[0].set_title('En Popüler 10 Şehirde Fiyat Dağılımı')
axes[0].set_ylabel('Fiyat (TL)')
axes[0].tick_params(axis='x', rotation=45) 
axes[0].ticklabel_format(style='plain', axis='y')

# --- 2.  İstanbul ---
sns.boxplot(data=df[df['Şehir'] == 'istanbul'], x='Şehir', y='Fiyat', palette='Set2', ax=axes[1], width=0.5)

axes[1].set_title('İstanbul Fiyat Dağılımı')
axes[1].set_ylabel('') 
axes[1].ticklabel_format(style='plain', axis='y')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\amets\AppData\Local\Temp\ipykernel_12716\4271868596.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df[df['Şehir'].isin(top_cities)], x='Şehir', y='Fiyat', palette='Set2', ax=axes[0])
# C:\Users\amets\AppData\Local\Temp\ipykernel_12716\4271868596.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df[df['Şehir'] == 'istanbul'], x='Şehir', y='Fiyat', palette='Set2', ax=axes[1], width=0.5)

# %% [markdown]
# ### Inferences
# Istanbul stands out with prices that are far higher and much more varied than anywhere else. Cities like Antalya lead the rest of the pack due to tourism, while inland areas remain significantly cheaper and more predictable. However, it’s interesting to see that regardless of the average cost, every single city still features a few ultra-luxury outliers that hit the price ceiling, proving that expensive real estate exists everywhere.

# %% [markdown]
# # Encoding Categorical Columns

# %%
print("----------Encoding object columns----------")
# Out:
# ----------Encoding object columns----------

# %%
# Importing functionality
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
# Defining target and seperating non-encoded from encoded data
target_col ='Fiyat'
df_encoded = df.copy()

# %% [markdown]
# ## One-Hot Encoding

# %%
cols_to_ohe=['Şehir','Isıtma_Tipi','Kullanım_Durumu','Tapu_Durumu']

# %%
df_encoded = pd.get_dummies(df_encoded, columns=cols_to_ohe, drop_first=True)

# %% [markdown]
# ## Label Encoding

# %%
cols_to_le = ['Takas' ,'Eşya_Durumu', 'Yatırıma_Uygunluk']

# %%
label_encoders = {}
for col in cols_to_le :
    le = LabelEncoder()
    df_encoded[col] = le.fit_transform(df_encoded[col].astype(str))
    label_encoders[col] = le

# %% [markdown]
# ## Removing Text Parts from Columns

# %%
cols_to_rt = ['Binanın_Yaşı', 'Bulunduğu_Kat']

# %%
import re

def remove_text1(veri):
    sayilar = [float(s) for s in re.findall(r'\d+', str(veri))]
    
    if len(sayilar) == 2:
        return sum(sayilar) / 2
    
    elif len(sayilar) == 1:
        return sayilar[0]
    
    return None

df_encoded['Binanın_Yaşı'] = df_encoded['Binanın_Yaşı'].apply(remove_text1).astype(float)

# %%
def remove_text2(data):
    yazi = str(data).lower()
    
    if "giriş" in yazi or "zemin" in yazi or "bahçe" in yazi:
        return 0
    
    sayilar = re.findall(r'\d+', yazi)
    if sayilar:
        return float(sayilar[0])
    return None

df_encoded['Bulunduğu_Kat'] = df_encoded['Bulunduğu_Kat'].apply(remove_text2).astype(float)

# %%
y = df_encoded['Fiyat'].astype(int)
X = df_encoded.drop('Fiyat', axis=1)

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
df.head()
# Out:
# X shape: (20326, 81)
# y shape: (20326,)
#    Net_Metrekare  Brüt_Metrekare  Oda_Sayısı      Bulunduğu_Kat Eşya_Durumu  \
# 0            120           150.0         4.0              4.Kat      Eşyalı
# 1            100           125.0         4.0              3.Kat         Boş
# 2             89            95.0         3.0              4.Kat         Boş
# 3             40            55.0         2.0              6.Kat         Boş
# 4            140           150.0         4.0  Düz Giriş (Zemin)         Boş
#
#   Binanın_Yaşı     Isıtma_Tipi      Fiyat  Şehir  Binanın_Kat_Sayısı  \
# 0  21 Ve Üzeri  Kombi Doğalgaz   950000.0  adana                   6
# 1            4  Kombi Doğalgaz  1250000.0  adana                  10
# 2     0 (Yeni)  Kombi Doğalgaz  1750000.0  adana                  14
# 3     0 (Yeni)  Kombi Doğalgaz  1300000.0  adana                  14
# 4         5-10         Klimalı  1700000.0  adana                   4
#
#   Kullanım_Durumu Yatırıma_Uygunluk Takas    Tapu_Durumu  Banyo_Sayısı
# 0             Boş               NaN   Var  Kat Mülkiyeti           1.0
# 1             Boş               NaN   Var            NaN           1.0
# 2             Boş             Uygun   Var            NaN           1.0
# 3             Boş             Uygun   Yok            NaN           1.0
# 4             Boş             Uygun   Yok  Kat Mülkiyeti           1.0

# %%
df_encoded.head()
# Out:
#    Net_Metrekare  Brüt_Metrekare  Oda_Sayısı  Bulunduğu_Kat  Eşya_Durumu  \
# 0            120           150.0         4.0            4.0            1
# 1            100           125.0         4.0            3.0            0
# 2             89            95.0         3.0            4.0            0
# 3             40            55.0         2.0            6.0            0
# 4            140           150.0         4.0            0.0            0
#
#    Binanın_Yaşı      Fiyat  Binanın_Kat_Sayısı  Yatırıma_Uygunluk  Takas  ...  \
# 0          21.0   950000.0                   6                  2      0  ...
# 1           4.0  1250000.0                  10                  2      0  ...
# 2           0.0  1750000.0                  14                  1      0  ...
# 3           0.0  1300000.0                  14                  1      1  ...
# 4           7.5  1700000.0                   4                  1      1  ...
#
#    Isıtma_Tipi_Merkezi Kömür  Isıtma_Tipi_Sobalı  Isıtma_Tipi_Yerden Isıtma  \
# 0                      False               False                      False
# 1                      False               False                      False
# 2                      False               False                      False
# 3                      False               False                      False
# 4                      False               False                      False
#
#    Kullanım_Durumu_Kiracı Oturuyor  Kullanım_Durumu_Mülk Sahibi Oturuyor  \
# 0                            False                                 False
# 1                            False                                 False
# 2                            False                                 False
# 3                            False                                 False
# 4                            False                                 False
#
#    Tapu_Durumu_Bilinmiyor  Tapu_Durumu_Hisseli Tapu  \
# 0                   False                     False
# 1                   False                     False
# 2                   False                     False
# 3                   False                     False
# 4                   False                     False
#
#    Tapu_Durumu_Kat Mülkiyeti  Tapu_Durumu_Kat İrtifakı  \
# 0                       True                     False
# 1                      False                     False
# 2                      False                     False
# 3                      False                     False
# 4                       True                     False
#
#    Tapu_Durumu_Müstakil Tapulu
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
#
# [5 rows x 82 columns]

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20326 entries, 0 to 20325
# Data columns (total 82 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Net_Metrekare                         20326 non-null  int64
#  1   Brüt_Metrekare                        20326 non-null  float64
#  2   Oda_Sayısı                            20066 non-null  float64
#  3   Bulunduğu_Kat                         17352 non-null  float64
#  4   Eşya_Durumu                           20326 non-null  int64
#  5   Binanın_Yaşı                          20326 non-null  float64
#  6   Fiyat                                 20326 non-null  float64
#  7   Binanın_Kat_Sayısı                    20326 non-null  int64
#  8   Yatırıma_Uygunluk                     20326 non-null  int64
#  9   Takas                                 20326 non-null  int64
#  10  Banyo_Sayısı                          20280 non-null  float64
#  11  Şehir_adiyaman                        20326 non-null  bool
#  12  Şehir_afyonkarahisar                  20326 non-null  bool
#  13  Şehir_agri                            20326 non-null  bool
#  14  Şehir_aksaray                         20326 non-null  bool
#  15  Şehir_amasya                          20326 non-null  bool
#  16  Şehir_ankara                          20326 non-null  bool
#  17  Şehir_antalya                         20326 non-null  bool
#  18  Şehir_ardahan                         20326 non-null  bool
#  19  Şehir_artvin                          20326 non-null  bool
#  20  Şehir_aydin                           20326 non-null  bool
#  21  Şehir_balikesir                       20326 non-null  bool
#  22  Şehir_bartin                          20326 non-null  bool
#  23  Şehir_batman                          20326 non-null  bool
#  24  Şehir_bayburt                         20326 non-null  bool
#  25  Şehir_bilecik                         20326 non-null  bool
#  26  Şehir_bingol                          20326 non-null  bool
#  27  Şehir_bitlis                          20326 non-null  bool
#  28  Şehir_bolu                            20326 non-null  bool
#  29  Şehir_burdur                          20326 non-null  bool
#  30  Şehir_bursa                           20326 non-null  bool
#  31  Şehir_canakkale                       20326 non-null  bool
#  32  Şehir_cankiri                         20326 non-null  bool
#  33  Şehir_corum                           20326 non-null  bool
#  34  Şehir_denizli                         20326 non-null  bool
#  35  Şehir_diyarbakir                      20326 non-null  bool
#  36  Şehir_duzce                           20326 non-null  bool
#  37  Şehir_edirne                          20326 non-null  bool
#  38  Şehir_elazig                          20326 non-null  bool
#  39  Şehir_erzincan                        20326 non-null  bool
#  40  Şehir_erzurum                         20326 non-null  bool
#  41  Şehir_eskisehir                       20326 non-null  bool
#  42  Şehir_gaziantep                       20326 non-null  bool
#  43  Şehir_giresun                         20326 non-null  bool
#  44  Şehir_gumushane                       20326 non-null  bool
#  45  Şehir_hakkari                         20326 non-null  bool
#  46  Şehir_hatay                           20326 non-null  bool
#  47  Şehir_igdir                           20326 non-null  bool
#  48  Şehir_isparta                         20326 non-null  bool
#  49  Şehir_istanbul                        20326 non-null  bool
#  50  Şehir_izmir                           20326 non-null  bool
#  51  Şehir_kahramanmaras                   20326 non-null  bool
#  52  Şehir_karabuk                         20326 non-null  bool
#  53  Şehir_karaman                         20326 non-null  bool
#  54  Şehir_kars                            20326 non-null  bool
#  55  Şehir_kastamonu                       20326 non-null  bool
#  56  Şehir_kayseri                         20326 non-null  bool
#  57  Şehir_kilis                           20326 non-null  bool
#  58  Şehir_kirikkale                       20326 non-null  bool
#  59  Şehir_kirklareli                      20326 non-null  bool
#  60  Şehir_kirsehir                        20326 non-null  bool
#  61  Şehir_kocaeli                         20326 non-null  bool
#  62  Şehir_konya                           20326 non-null  bool
#  63  Isıtma_Tipi_Doğalgaz Sobalı           20326 non-null  bool
#  64  Isıtma_Tipi_Güneş Enerjisi            20326 non-null  bool
#  65  Isıtma_Tipi_Isıtma Yok                20326 non-null  bool
#  66  Isıtma_Tipi_Jeotermal                 20326 non-null  bool
#  67  Isıtma_Tipi_Kat Kaloriferi            20326 non-null  bool
#  68  Isıtma_Tipi_Klimalı                   20326 non-null  bool
#  69  Isıtma_Tipi_Kombi Doğalgaz            20326 non-null  bool
#  70  Isıtma_Tipi_Merkezi (Pay Ölçer)       20326 non-null  bool
#  71  Isıtma_Tipi_Merkezi Doğalgaz          20326 non-null  bool
#  72  Isıtma_Tipi_Merkezi Kömür             20326 non-null  bool
#  73  Isıtma_Tipi_Sobalı                    20326 non-null  bool
#  74  Isıtma_Tipi_Yerden Isıtma             20326 non-null  bool
#  75  Kullanım_Durumu_Kiracı Oturuyor       20326 non-null  bool
#  76  Kullanım_Durumu_Mülk Sahibi Oturuyor  20326 non-null  bool
#  77  Tapu_Durumu_Bilinmiyor                20326 non-null  bool
#  78  Tapu_Durumu_Hisseli Tapu              20326 non-null  bool
#  79  Tapu_Durumu_Kat Mülkiyeti             20326 non-null  bool
#  80  Tapu_Durumu_Kat İrtifakı              20326 non-null  bool
#  81  Tapu_Durumu_Müstakil Tapulu           20326 non-null  bool
# dtypes: bool(71), float64(6), int64(5)
# memory usage: 3.1 MB

# %% [markdown]
# ### Splitting data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X,           # Input DataFrame of features
    y,       # Input Series of the target
    test_size=0.2, # Using 20% for the test set this time
    random_state=42 # Ensures reproducibility
)

# %% [markdown]
# ### Checking label encoded features for outliers

# %%
df["Takas"].value_counts()
# Out:
# Takas
# Yok    9628
# Var    4803
# Name: count, dtype: int64

# %%
df["Eşya_Durumu"].value_counts()
# Out:
# Eşya_Durumu
# Boş       11167
# Eşyalı     1761
# Name: count, dtype: int64

# %% [markdown]
# ### Scaling numerical features

# %%
# Importing functionality
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16260 entries, 20180 to 15795
# Data columns (total 81 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Net_Metrekare                         16260 non-null  int64
#  1   Brüt_Metrekare                        16260 non-null  float64
#  2   Oda_Sayısı                            16042 non-null  float64
#  3   Bulunduğu_Kat                         13867 non-null  float64
#  4   Eşya_Durumu                           16260 non-null  int64
#  5   Binanın_Yaşı                          16260 non-null  float64
#  6   Binanın_Kat_Sayısı                    16260 non-null  int64
#  7   Yatırıma_Uygunluk                     16260 non-null  int64
#  8   Takas                                 16260 non-null  int64
#  9   Banyo_Sayısı                          16228 non-null  float64
#  10  Şehir_adiyaman                        16260 non-null  bool
#  11  Şehir_afyonkarahisar                  16260 non-null  bool
#  12  Şehir_agri                            16260 non-null  bool
#  13  Şehir_aksaray                         16260 non-null  bool
#  14  Şehir_amasya                          16260 non-null  bool
#  15  Şehir_ankara                          16260 non-null  bool
#  16  Şehir_antalya                         16260 non-null  bool
#  17  Şehir_ardahan                         16260 non-null  bool
#  18  Şehir_artvin                          16260 non-null  bool
#  19  Şehir_aydin                           16260 non-null  bool
#  20  Şehir_balikesir                       16260 non-null  bool
#  21  Şehir_bartin                          16260 non-null  bool
#  22  Şehir_batman                          16260 non-null  bool
#  23  Şehir_bayburt                         16260 non-null  bool
#  24  Şehir_bilecik                         16260 non-null  bool
#  25  Şehir_bingol                          16260 non-null  bool
#  26  Şehir_bitlis                          16260 non-null  bool
#  27  Şehir_bolu                            16260 non-null  bool
#  28  Şehir_burdur                          16260 non-null  bool
#  29  Şehir_bursa                           16260 non-null  bool
#  30  Şehir_canakkale                       16260 non-null  bool
#  31  Şehir_cankiri                         16260 non-null  bool
#  32  Şehir_corum                           16260 non-null  bool
#  33  Şehir_denizli                         16260 non-null  bool
#  34  Şehir_diyarbakir                      16260 non-null  bool
#  35  Şehir_duzce                           16260 non-null  bool
#  36  Şehir_edirne                          16260 non-null  bool
#  37  Şehir_elazig                          16260 non-null  bool
#  38  Şehir_erzincan                        16260 non-null  bool
#  39  Şehir_erzurum                         16260 non-null  bool
#  40  Şehir_eskisehir                       16260 non-null  bool
#  41  Şehir_gaziantep                       16260 non-null  bool
#  42  Şehir_giresun                         16260 non-null  bool
#  43  Şehir_gumushane                       16260 non-null  bool
#  44  Şehir_hakkari                         16260 non-null  bool
#  45  Şehir_hatay                           16260 non-null  bool
#  46  Şehir_igdir                           16260 non-null  bool
#  47  Şehir_isparta                         16260 non-null  bool
#  48  Şehir_istanbul                        16260 non-null  bool
#  49  Şehir_izmir                           16260 non-null  bool
#  50  Şehir_kahramanmaras                   16260 non-null  bool
#  51  Şehir_karabuk                         16260 non-null  bool
#  52  Şehir_karaman                         16260 non-null  bool
#  53  Şehir_kars                            16260 non-null  bool
#  54  Şehir_kastamonu                       16260 non-null  bool
#  55  Şehir_kayseri                         16260 non-null  bool
#  56  Şehir_kilis                           16260 non-null  bool
#  57  Şehir_kirikkale                       16260 non-null  bool
#  58  Şehir_kirklareli                      16260 non-null  bool
#  59  Şehir_kirsehir                        16260 non-null  bool
#  60  Şehir_kocaeli                         16260 non-null  bool
#  61  Şehir_konya                           16260 non-null  bool
#  62  Isıtma_Tipi_Doğalgaz Sobalı           16260 non-null  bool
#  63  Isıtma_Tipi_Güneş Enerjisi            16260 non-null  bool
#  64  Isıtma_Tipi_Isıtma Yok                16260 non-null  bool
#  65  Isıtma_Tipi_Jeotermal                 16260 non-null  bool
#  66  Isıtma_Tipi_Kat Kaloriferi            16260 non-null  bool
#  67  Isıtma_Tipi_Klimalı                   16260 non-null  bool
#  68  Isıtma_Tipi_Kombi Doğalgaz            16260 non-null  bool
#  69  Isıtma_Tipi_Merkezi (Pay Ölçer)       16260 non-null  bool
#  70  Isıtma_Tipi_Merkezi Doğalgaz          16260 non-null  bool
#  71  Isıtma_Tipi_Merkezi Kömür             16260 non-null  bool
#  72  Isıtma_Tipi_Sobalı                    16260 non-null  bool
#  73  Isıtma_Tipi_Yerden Isıtma             16260 non-null  bool
#  74  Kullanım_Durumu_Kiracı Oturuyor       16260 non-null  bool
#  75  Kullanım_Durumu_Mülk Sahibi Oturuyor  16260 non-null  bool
#  76  Tapu_Durumu_Bilinmiyor                16260 non-null  bool
#  77  Tapu_Durumu_Hisseli Tapu              16260 non-null  bool
#  78  Tapu_Durumu_Kat Mülkiyeti             16260 non-null  bool
#  79  Tapu_Durumu_Kat İrtifakı              16260 non-null  bool
#  80  Tapu_Durumu_Müstakil Tapulu           16260 non-null  bool
# dtypes: bool(71), float64(5), int64(5)
# memory usage: 2.5 MB

# %%
# Defining the columns I want to scale
numerical_features_to_scale = ['Net_Metrekare','Brüt_Metrekare','Oda_Sayısı','Binanın_Kat_Sayısı','Banyo_Sayısı']

# %%
# Scaling and fitting scaler
scaler = StandardScaler()
scaler.fit(x_train[numerical_features_to_scale])
# Out:
# StandardScaler()

# %%
# Transforming with scaler
x_train[numerical_features_to_scale] = scaler.transform(x_train[numerical_features_to_scale])
x_test[numerical_features_to_scale] = scaler.transform(x_test[numerical_features_to_scale])

# %%
# Scaling done!

# %% [markdown]
# # Training, evaluating, and tuning a Random Forest model

# %% [markdown]
# ## Training the model

# %%
# Importing functionality
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier

# %%
# Initializing and fitting model
rf_model = RandomForestRegressor(
    n_estimators=150,      # stable, good accuracy
    max_depth=6,          # prevents RAM blow-up
    min_samples_split=20,   # smoother splits
    min_samples_leaf=10,    # reduces overfitting
    max_features="sqrt",   # best for classification
    n_jobs=1,              # avoid parallel-memory explosion
    random_state=42
)
rf_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=6, max_features='sqrt', min_samples_leaf=10,
#                       min_samples_split=20, n_estimators=150, n_jobs=1,
#                       random_state=42)

# %%
# Runiing initial predictions
y_pred_rf = rf_model.predict(x_test)

# %% [markdown]
# ## Evaluating the model

# %%
# Checking for overfitting
print(rf_model.score(x_train, y_train))
print(rf_model.score(x_test, y_test))
# Out:
# 0.5505511125641352
# 0.5000867188170877

# %% [markdown]
# #### Note on evaluation criteria
# Since it's a regression problem, not a classification problem, accuracy and recall are not really meaningful here.  Accuracy only applies to classification. Here, there's no one correct class to get right (e.g sick or not sick), but a whole range of them.
# The target is continous, so we should focus less on getting the exact same number, as there's just too many, and more on getting the least possible error, because at the scale of a house purchase, a model that is off by only a few thousand lira is irrelevant.
# If someone is buying a house and the error is the same price as a pair of shoes or a good jacket, at the scale of the financing the buyer has ready, that's likely to be acceptable. The same goes for someone trying to sell a house: If the model underpriced their house they can just try to negotiate up, and if not, if you're selling a house for a million lira, you probably wouldn't risk the deal for 5k or even 10k.
# So our 3 criteria are as follows:
#
# &nbsp;&nbsp;&nbsp;&nbsp;Mean Absolute error(MAE): How many lira, plus or minus, is the model off by on average?
# &nbsp;&nbsp;&nbsp;&nbsp;Root Mean Squared Error(RMSE): How big are the mistakes when they are made?
# &nbsp;&nbsp;&nbsp;&nbsp;R^2 score: How much is the model able to guess how different variable affect pricing, where 1 means it understands fully and 0 means it's not much different from making a random guess.

# %% [markdown]
# ### Checking MAE

# %%
# Importing functionality
from sklearn.metrics import mean_absolute_error

# %%
# Checking and printing MAE
mae = mean_absolute_error(y_test, y_pred_rf)
print("MAE: {:,.0f} TRY".format(mae))
# Out:
# MAE: 1,157,021 TRY

# %% [markdown]
# ### Checking RMSE

# %%
# Importing functionality
from sklearn.metrics import mean_squared_error

# %%
# Checking and printing
rmse = mean_squared_error(y_test, y_pred_rf)
print("RMSE: {:,.0f} TRY".format(rmse))
# Out:
# RMSE: 4,257,222,622,222 TRY

# %% [markdown]
# ### Checking R^2

# %%
# Importing functionality
from sklearn.metrics import r2_score

# %%
# Checking and printing
r2 = r2_score(y_test, y_pred_rf)
print("R²:", r2)
# Out:
# R²: 0.5000867188170877

# %% [markdown]
# ### Initial assessment:
# The model is so broken, odds are a bigger data quality issue is at play here

# %% [markdown]
# ### Attempting to diagnose data quality issue

# %%
# Checking range of values in y
y.describe()
# Out:
# count    2.032600e+04
# mean     3.128497e+06
# std      2.988716e+06
# min      6.112500e+05
# 25%      1.640000e+06
# 50%      2.300000e+06
# 75%      3.300000e+06
# max      1.983750e+07
# Name: Fiyat, dtype: float64

# %%
# Looking at describe, the max is 7.5 billion, but the median is 2.3 million, and the mean is 
# 4.6 million. The extreme outliers are breaking the code. We need to remove or plug in median for the most extreme
# outliers to fix the issue

# %%
# The issue is with y's outliers.

# %%
# Final evaluation metrics
print(f"R² Score: {r2_score(y_test, y_pred_rf):.4f}")
print(f"MAE: {mean_absolute_error(y_test, y_pred_rf):,.0f} TL")
print(f"RMSE: {mean_squared_error(y_test, y_pred_rf, squared=False):,.0f} TL")
# Out:
# R² Score: 0.5001
# MAE: 1,157,021 TL
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[740], line 4
#       2 print(f"R² Score: {r2_score(y_test, y_pred_rf):.4f}")
#       3 print(f"MAE: {mean_absolute_error(y_test, y_pred_rf):,.0f} TL")
# ----> 4 print(f"RMSE: {mean_squared_error(y_test, y_pred_rf, squared=False):,.0f} TL")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\inspect.py:3195, in Signature.bind(self, *args, **kwargs)
#    3190 def bind(self, /, *args, **kwargs):
#    3191     """Get a BoundArguments object, that maps the passed `args`
#    3192     and `kwargs` to the function's signature.  Raises `TypeError`
#    3193     if the passed arguments can not be bound.
#    3194     """
# -> 3195     return self._bind(args, kwargs)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\inspect.py:3184, in Signature._bind(self, args, kwargs, partial)
#    3182         arguments[kwargs_param.name] = kwargs
#    3183     else:
# -> 3184         raise TypeError(
#    3185             'got an unexpected keyword argument {arg!r}'.format(
#    3186                 arg=next(iter(kwargs))))
#    3188 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'squared'
